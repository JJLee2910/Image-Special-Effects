# %%
import cv2
import numpy as np

# %%
class KeypointsDetector:
    def __init__(self, image_path):
        self.image = cv2.imread(image_path)
        self.gray = None
        self.original_keypoints = None
        self.original_descriptor = None
        self.keypoints_without_size = None
        self.keypoints_with_size = None

    def preprocess(self):
        # Resize image
        self.image = cv2.resize(self.image, (0, 0), fx=0.25, fy=0.25)

        # Convert to grayscale
        self.gray = cv2.cvtColor(self.image, cv2.COLOR_BGR2GRAY)

        # Apply Gaussian blur
        self.gray = cv2.GaussianBlur(self.gray, (5, 5), 0)

        # Apply histogram equalization
        self.gray = cv2.equalizeHist(self.gray)

    def detect_keypoints(self):
        sift = cv2.SIFT_create()
        self.original_keypoints, self.original_descriptor = sift.detectAndCompute(self.gray, None)
        self.keypoints_without_size = np.copy(self.image)
        cv2.drawKeypoints(self.image, self.original_keypoints, self.keypoints_without_size, color=(0, 255, 0))

        self.keypoints_with_size = np.copy(self.image)
        cv2.drawKeypoints(self.image, self.original_keypoints, self.keypoints_with_size,
                          flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

    def show_keypoints(self):
        for i in self.original_keypoints:
            x, y = i.pt
            print(f"Keypoint at ({x:.2f}, {y:.2f})")

        cv2.imshow('Keypoints without size', self.keypoints_without_size)
        cv2.imshow('Keypoints with size', self.keypoints_with_size)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

if __name__ == '__main__':
    detector = KeypointsDetector('eye_image/eyes_front_Side.jpg')
    detector.preprocess()
    detector.detect_keypoints()
    detector.show_keypoints()
# Out:
# Keypoint at (3.04, 311.64)
# Keypoint at (4.45, 363.53)
# Keypoint at (4.47, 329.49)
# Keypoint at (5.13, 57.05)
# Keypoint at (6.03, 300.81)
# Keypoint at (6.92, 92.17)
# Keypoint at (8.24, 309.44)
# Keypoint at (8.24, 309.44)
# Keypoint at (8.36, 334.99)
# Keypoint at (9.45, 245.39)
# Keypoint at (10.55, 539.23)
# Keypoint at (10.55, 539.23)
# Keypoint at (10.82, 341.77)
# Keypoint at (11.53, 270.41)
# Keypoint at (11.78, 248.05)
# Keypoint at (13.13, 167.20)
# Keypoint at (14.04, 39.73)
# Keypoint at (14.04, 39.73)
# Keypoint at (14.12, 147.88)
# Keypoint at (16.57, 303.25)
# Keypoint at (16.95, 247.91)
# Keypoint at (17.11, 310.66)
# Keypoint at (18.36, 50.29)
# Keypoint at (18.36, 50.29)
# Keypoint at (18.36, 50.29)
# Keypoint at (18.80, 105.79)
# Keypoint at (20.04, 102.95)
# Keypoint at (20.65, 37.93)
# Keypoint at (20.70, 364.92)
# Keypoint at (20.83, 259.48)
# Keypoint at (21.06, 329.19)
# Keypoint at (21.06, 329.19)
# Keypoint at (22.12, 160.37)
# Keypoint at (22.62, 535.29)
# Keypoint at (23.48, 179.27)
# Keypoint at (23.50, 480.12)
# Keypoint at (24.12, 324.66)
# Keypoint at (24.12, 324.66)
# Keypoint at (25.09, 91.37)
# Keypoint at (25.71, 41.02)
# Keypoint at (26.79, 344.14)
# Keypoint at (27.23, 354.19)
# Keypoint at (27.23, 354.19)
# Keypoint at (27.39, 353.79)
# Keypoint at (27.39, 353.79)
# Keypoint at (28.95, 198.80)
# Keypoint at (30.25, 313.14)
# Keypoint at (30.98, 307.86)
# Keypoint at (31.01, 485.13)
# Keypoint at (31.15, 500.47)
# Keypoint at (31.27, 284.34)
# Keypoint at (31.60, 62.59)
# Keypoint at (33.09, 296.92)
# Keypoint at (35.21, 354.55)
# Keypoint at (35.68, 53.31)
# Keypoint at (35.94, 509.93)
# Keypoint at (35.96, 497.43)
# Keypoint at (36.36, 472.06)
# Keypoint at (37.04, 518.72)
# Keypoint at (37.74, 103.14)
# Keypoint at (37.78, 68.79)
# Keypoint at (37.85, 293.67)
# Keypoint at (37.91, 84.70)
# Keypoint at (38.06, 479.21)
# Keypoint at (38.68, 197.67)
# Keypoint at (39.01, 525.33)
# Keypoint at (39.04, 500.48)
# Keypoint at (39.07, 507.93)
# Keypoint at (39.37, 492.58)
# Keypoint at (39.37, 492.58)
# Keypoint at (39.41, 301.89)
# Keypoint at (40.54, 504.22)
# Keypoint at (40.54, 504.22)
# Keypoint at (40.68, 309.49)
# Keypoint at (41.00, 209.54)
# Keypoint at (41.12, 168.62)
# Keypoint at (41.40, 531.57)
# Keypoint at (42.93, 519.71)
# Keypoint at (43.18, 360.29)
# Keypoint at (43.66, 333.67)
# Keypoint at (43.66, 333.67)
# Keypoint at (43.72, 246.07)
# Keypoint at (43.72, 246.07)
# Keypoint at (43.81, 526.45)
# Keypoint at (44.06, 110.45)
# Keypoint at (44.20, 485.89)
# Keypoint at (44.78, 110.84)
# Keypoint at (45.52, 502.57)
# Keypoint at (45.64, 280.91)
# Keypoint at (45.73, 506.99)
# Keypoint at (46.37, 319.20)
# Keypoint at (47.27, 114.55)
# Keypoint at (48.08, 356.07)
# Keypoint at (48.35, 494.13)
# Keypoint at (49.46, 510.88)
# Keypoint at (49.78, 309.19)
# Keypoint at (51.26, 186.11)
# Keypoint at (51.26, 186.11)
# Keypoint at (52.97, 539.24)
# Keypoint at (53.10, 340.91)
# Keypoint at (53.10, 340.91)
# Keypoint at (53.74, 150.26)
# Keypoint at (53.85, 522.82)
# Keypoint at (53.91, 149.97)
# Keypoint at (54.07, 284.21)
# Keypoint at (54.14, 4.68)
# Keypoint at (54.66, 117.54)
# Keypoint at (55.17, 311.77)
# Keypoint at (56.38, 147.66)
# Keypoint at (56.48, 260.63)
# Keypoint at (57.41, 204.67)
# Keypoint at (57.41, 204.67)
# Keypoint at (58.38, 364.31)
# Keypoint at (58.38, 364.31)
# Keypoint at (59.40, 523.85)
# Keypoint at (60.35, 150.48)
# Keypoint at (61.22, 248.60)
# Keypoint at (64.31, 53.07)
# Keypoint at (64.32, 311.17)
# Keypoint at (64.67, 490.50)
# Keypoint at (64.84, 67.78)
# Keypoint at (64.96, 292.73)
# Keypoint at (65.25, 315.54)
# Keypoint at (65.86, 338.36)
# Keypoint at (66.11, 99.78)
# Keypoint at (66.34, 122.24)
# Keypoint at (67.37, 60.42)
# Keypoint at (70.18, 454.74)
# Keypoint at (70.75, 325.24)
# Keypoint at (70.93, 330.75)
# Keypoint at (71.06, 47.67)
# Keypoint at (71.06, 47.67)
# Keypoint at (73.73, 345.13)
# Keypoint at (73.81, 43.40)
# Keypoint at (74.96, 491.09)
# Keypoint at (76.02, 331.07)
# Keypoint at (76.29, 311.34)
# Keypoint at (76.61, 136.01)
# Keypoint at (76.61, 39.02)
# Keypoint at (76.61, 39.02)
# Keypoint at (79.24, 521.38)
# Keypoint at (79.46, 36.25)
# Keypoint at (79.87, 320.05)
# Keypoint at (80.03, 340.68)
# Keypoint at (80.03, 340.68)
# Keypoint at (80.19, 325.83)
# Keypoint at (82.80, 443.26)
# Keypoint at (82.80, 443.26)
# Keypoint at (83.88, 382.89)
# Keypoint at (83.88, 382.89)
# Keypoint at (84.01, 41.74)
# Keypoint at (84.74, 52.83)
# Keypoint at (84.74, 52.83)
# Keypoint at (86.65, 320.79)
# Keypoint at (86.91, 520.17)
# Keypoint at (87.07, 156.61)
# Keypoint at (88.19, 453.65)
# Keypoint at (88.78, 492.81)
# Keypoint at (89.92, 486.93)
# Keypoint at (90.27, 517.91)
# Keypoint at (91.72, 490.25)
# Keypoint at (92.56, 52.97)
# Keypoint at (92.64, 59.00)
# Keypoint at (94.41, 518.07)
# Keypoint at (94.90, 275.55)
# Keypoint at (94.90, 275.55)
# Keypoint at (95.84, 482.32)
# Keypoint at (96.22, 318.03)
# Keypoint at (96.44, 422.17)
# Keypoint at (96.95, 46.41)
# Keypoint at (96.96, 79.11)
# Keypoint at (96.96, 79.11)
# Keypoint at (98.34, 165.34)
# Keypoint at (98.52, 92.03)
# Keypoint at (100.23, 84.71)
# Keypoint at (101.45, 38.60)
# Keypoint at (103.66, 491.05)
# Keypoint at (105.62, 478.09)
# Keypoint at (105.62, 487.10)
# Keypoint at (105.82, 493.81)
# Keypoint at (108.52, 170.72)
# Keypoint at (108.59, 455.59)
# Keypoint at (108.74, 51.68)
# Keypoint at (109.57, 264.58)
# Keypoint at (111.08, 279.06)
# Keypoint at (111.96, 326.65)
# Keypoint at (112.84, 113.13)
# Keypoint at (114.93, 202.87)
# Keypoint at (115.61, 494.90)
# Keypoint at (122.13, 271.67)
# Keypoint at (123.78, 229.22)
# Keypoint at (124.14, 472.85)
# Keypoint at (125.31, 433.94)
# Keypoint at (125.95, 504.46)
# Keypoint at (127.48, 451.42)
# Keypoint at (127.57, 192.74)
# Keypoint at (127.57, 192.74)
# Keypoint at (128.03, 480.10)
# Keypoint at (128.48, 218.32)
# Keypoint at (128.48, 218.32)
# Keypoint at (128.86, 508.17)
# Keypoint at (128.86, 508.17)
# Keypoint at (129.79, 354.86)
# Keypoint at (130.15, 242.48)
# Keypoint at (130.15, 242.48)
# Keypoint at (130.15, 242.48)
# Keypoint at (130.25, 122.91)
# Keypoint at (130.47, 495.03)
# Keypoint at (130.47, 495.03)
# Keypoint at (130.53, 153.49)
# Keypoint at (130.53, 153.49)
# Keypoint at (130.79, 123.13)
# Keypoint at (131.79, 184.44)
# Keypoint at (132.28, 130.13)
# Keypoint at (133.91, 78.03)
# Keypoint at (135.12, 118.84)
# Keypoint at (135.12, 118.84)
# Keypoint at (135.17, 193.83)
# Keypoint at (135.20, 284.92)
# Keypoint at (138.26, 228.36)
# Keypoint at (138.26, 228.36)
# Keypoint at (138.33, 186.95)
# Keypoint at (139.20, 496.35)
# Keypoint at (139.20, 154.05)
# Keypoint at (139.74, 191.86)
# Keypoint at (140.40, 128.73)
# Keypoint at (141.18, 162.90)
# Keypoint at (145.04, 123.98)
# Keypoint at (146.69, 333.07)
# Keypoint at (147.26, 210.22)
# Keypoint at (148.38, 432.55)
# Keypoint at (148.86, 43.13)
# Keypoint at (148.96, 386.18)
# Keypoint at (151.81, 144.67)
# Keypoint at (151.81, 144.67)
# Keypoint at (155.34, 160.07)
# Keypoint at (155.98, 160.54)
# Keypoint at (156.30, 50.73)
# Keypoint at (156.71, 39.00)
# Keypoint at (157.03, 318.53)
# Keypoint at (157.73, 218.38)
# Keypoint at (157.99, 327.53)
# Keypoint at (159.78, 297.55)
# Keypoint at (159.78, 297.55)
# Keypoint at (160.88, 119.33)
# Keypoint at (160.88, 119.33)
# Keypoint at (163.42, 209.61)
# Keypoint at (163.46, 72.63)
# Keypoint at (163.81, 248.58)
# Keypoint at (164.03, 173.43)
# Keypoint at (165.97, 109.94)
# Keypoint at (166.01, 119.63)
# Keypoint at (166.30, 122.56)
# Keypoint at (166.82, 135.38)
# Keypoint at (166.86, 187.10)
# Keypoint at (167.13, 270.00)
# Keypoint at (168.82, 211.47)
# Keypoint at (169.03, 127.17)
# Keypoint at (170.60, 115.85)
# Keypoint at (171.01, 65.04)
# Keypoint at (171.29, 558.46)
# Keypoint at (171.90, 47.50)
# Keypoint at (172.49, 82.09)
# Keypoint at (172.77, 86.00)
# Keypoint at (173.13, 119.54)
# Keypoint at (173.72, 42.77)
# Keypoint at (174.17, 94.63)
# Keypoint at (174.17, 94.63)
# Keypoint at (174.58, 21.26)
# Keypoint at (174.58, 556.30)
# Keypoint at (174.58, 556.30)
# Keypoint at (175.22, 250.33)
# Keypoint at (175.84, 53.32)
# Keypoint at (175.99, 139.87)
# Keypoint at (175.99, 48.38)
# Keypoint at (176.16, 205.90)
# Keypoint at (176.75, 187.10)
# Keypoint at (177.53, 80.05)
# Keypoint at (177.84, 100.95)
# Keypoint at (177.89, 41.79)
# Keypoint at (177.89, 41.79)
# Keypoint at (178.11, 254.75)
# Keypoint at (178.11, 254.75)
# Keypoint at (178.26, 112.78)
# Keypoint at (178.28, 45.54)
# Keypoint at (178.62, 149.42)
# Keypoint at (179.42, 126.37)
# Keypoint at (179.59, 49.67)
# Keypoint at (179.95, 139.29)
# Keypoint at (180.91, 141.55)
# Keypoint at (180.99, 92.84)
# Keypoint at (181.30, 29.36)
# Keypoint at (181.48, 274.25)
# Keypoint at (182.11, 132.33)
# Keypoint at (182.11, 132.33)
# Keypoint at (182.50, 194.46)
# Keypoint at (183.09, 83.22)
# Keypoint at (183.09, 83.22)
# Keypoint at (183.72, 139.49)
# Keypoint at (184.06, 145.82)
# Keypoint at (184.65, 186.36)
# Keypoint at (185.67, 14.86)
# Keypoint at (185.70, 178.03)
# Keypoint at (186.13, 115.60)
# Keypoint at (186.57, 106.82)
# Keypoint at (186.70, 127.05)
# Keypoint at (186.89, 102.02)
# Keypoint at (187.20, 83.27)
# Keypoint at (187.45, 91.91)
# Keypoint at (189.22, 196.88)
# Keypoint at (190.01, 181.06)
# Keypoint at (190.03, 117.14)
# Keypoint at (192.04, 48.67)
# Keypoint at (192.95, 142.59)
# Keypoint at (193.12, 126.18)
# Keypoint at (194.80, 117.95)
# Keypoint at (194.86, 256.22)
# Keypoint at (194.92, 159.08)
# Keypoint at (195.01, 210.36)
# Keypoint at (195.01, 210.36)
# Keypoint at (195.89, 146.46)
# Keypoint at (196.15, 111.90)
# Keypoint at (196.15, 111.90)
# Keypoint at (197.86, 180.88)
# Keypoint at (198.01, 115.44)
# Keypoint at (198.04, 9.40)
# Keypoint at (198.33, 200.43)
# Keypoint at (198.56, 151.24)
# Keypoint at (198.56, 151.24)
# Keypoint at (198.79, 176.40)
# Keypoint at (198.85, 122.19)
# Keypoint at (200.70, 129.96)
# Keypoint at (200.70, 129.96)
# Keypoint at (201.06, 166.26)
# Keypoint at (201.39, 179.34)
# Keypoint at (201.39, 179.34)
# Keypoint at (202.29, 170.21)
# Keypoint at (202.41, 6.61)
# Keypoint at (202.95, 124.25)
# Keypoint at (202.95, 124.25)
# Keypoint at (203.55, 228.08)
# Keypoint at (203.83, 198.33)
# Keypoint at (204.60, 241.37)
# Keypoint at (204.60, 241.37)
# Keypoint at (205.21, 109.38)
# Keypoint at (205.64, 250.03)
# Keypoint at (205.64, 250.03)
# Keypoint at (206.37, 220.13)
# Keypoint at (206.51, 215.24)
# Keypoint at (206.68, 140.05)
# Keypoint at (207.01, 9.62)
# Keypoint at (207.37, 186.65)
# Keypoint at (208.71, 118.12)
# Keypoint at (208.79, 224.67)
# Keypoint at (209.80, 112.64)
# Keypoint at (210.41, 219.61)
# Keypoint at (210.41, 219.61)
# Keypoint at (210.68, 233.65)
# Keypoint at (210.68, 233.65)
# Keypoint at (210.77, 12.02)
# Keypoint at (212.61, 6.15)
# Keypoint at (213.07, 228.03)
# Keypoint at (214.58, 210.39)
# Keypoint at (215.10, 134.24)
# Keypoint at (215.38, 177.79)
# Keypoint at (215.38, 177.79)
# Keypoint at (215.65, 156.28)
# Keypoint at (216.27, 205.81)
# Keypoint at (217.74, 224.44)
# Keypoint at (217.74, 224.44)
# Keypoint at (217.80, 123.96)
# Keypoint at (217.80, 123.96)
# Keypoint at (218.17, 129.94)
# Keypoint at (218.22, 194.73)
# Keypoint at (218.22, 194.73)
# Keypoint at (218.35, 557.86)
# Keypoint at (218.70, 135.19)
# Keypoint at (219.08, 139.22)
# Keypoint at (219.66, 356.86)
# Keypoint at (219.66, 356.86)
# Keypoint at (219.66, 356.86)
# Keypoint at (219.77, 150.91)
# Keypoint at (220.07, 438.40)
# Keypoint at (220.30, 227.45)
# Keypoint at (220.65, 127.09)
# Keypoint at (220.93, 230.56)
# Keypoint at (220.93, 230.56)
# Keypoint at (221.00, 560.86)
# Keypoint at (221.05, 344.37)
# Keypoint at (221.70, 374.23)
# Keypoint at (221.91, 6.40)
# Keypoint at (222.22, 9.57)
# Keypoint at (223.57, 199.16)
# Keypoint at (223.57, 199.16)
# Keypoint at (224.55, 225.09)
# Keypoint at (225.23, 346.72)
# Keypoint at (225.47, 154.98)
# Keypoint at (225.63, 396.66)
# Keypoint at (225.64, 166.93)
# Keypoint at (226.18, 211.01)
# Keypoint at (226.42, 221.68)
# Keypoint at (226.52, 6.90)
# Keypoint at (226.81, 205.00)
# Keypoint at (226.89, 192.07)
# Keypoint at (227.09, 144.41)
# Keypoint at (228.87, 102.13)
# Keypoint at (229.06, 216.77)
# Keypoint at (229.06, 216.77)
# Keypoint at (230.00, 558.98)
# Keypoint at (230.15, 199.26)
# Keypoint at (230.35, 75.79)
# Keypoint at (230.77, 9.26)
# Keypoint at (230.81, 190.45)
# Keypoint at (231.05, 233.21)
# Keypoint at (231.48, 205.47)
# Keypoint at (231.49, 228.01)
# Keypoint at (231.49, 228.01)
# Keypoint at (231.86, 210.25)
# Keypoint at (231.89, 123.27)
# Keypoint at (232.41, 215.84)
# Keypoint at (232.94, 456.43)
# Keypoint at (233.56, 196.91)
# Keypoint at (233.76, 332.42)
# Keypoint at (233.99, 307.70)
# Keypoint at (234.11, 143.11)
# Keypoint at (234.11, 143.11)
# Keypoint at (235.24, 188.94)
# Keypoint at (235.81, 218.76)
# Keypoint at (235.81, 218.76)
# Keypoint at (235.90, 135.69)
# Keypoint at (237.18, 193.72)
# Keypoint at (237.24, 111.79)
# Keypoint at (237.24, 111.79)
# Keypoint at (237.28, 182.18)
# Keypoint at (237.34, 197.32)
# Keypoint at (237.49, 312.90)
# Keypoint at (237.69, 337.80)
# Keypoint at (238.62, 561.80)
# Keypoint at (238.90, 6.02)
# Keypoint at (239.09, 208.18)
# Keypoint at (239.51, 451.95)
# Keypoint at (239.92, 239.03)
# Keypoint at (240.29, 114.87)
# Keypoint at (240.80, 199.00)
# Keypoint at (241.35, 446.19)
# Keypoint at (241.48, 193.80)
# Keypoint at (241.48, 99.22)
# Keypoint at (242.53, 455.47)
# Keypoint at (242.81, 226.44)
# Keypoint at (243.03, 203.15)
# Keypoint at (243.03, 203.15)
# Keypoint at (243.40, 315.06)
# Keypoint at (243.84, 7.02)
# Keypoint at (243.98, 196.69)
# Keypoint at (245.09, 13.38)
# Keypoint at (245.37, 127.05)
# Keypoint at (245.96, 94.05)
# Keypoint at (246.18, 445.69)
# Keypoint at (246.34, 136.27)
# Keypoint at (246.40, 117.61)
# Keypoint at (246.41, 299.88)
# Keypoint at (246.82, 200.34)
# Keypoint at (246.92, 219.55)
# Keypoint at (248.54, 318.79)
# Keypoint at (249.57, 562.55)
# Keypoint at (249.91, 451.09)
# Keypoint at (250.18, 13.65)
# Keypoint at (251.23, 445.61)
# Keypoint at (251.23, 445.61)
# Keypoint at (251.75, 462.05)
# Keypoint at (253.56, 103.74)
# Keypoint at (254.03, 323.26)
# Keypoint at (254.29, 451.03)
# Keypoint at (255.22, 562.65)
# Keypoint at (255.39, 460.02)
# Keypoint at (255.69, 243.76)
# Keypoint at (256.18, 13.60)
# Keypoint at (256.31, 251.28)
# Keypoint at (256.46, 435.50)
# Keypoint at (256.87, 447.10)
# Keypoint at (258.78, 365.00)
# Keypoint at (260.38, 193.37)
# Keypoint at (260.72, 309.33)
# Keypoint at (261.84, 252.30)
# Keypoint at (261.84, 252.30)
# Keypoint at (263.25, 282.89)
# Keypoint at (263.29, 236.18)
# Keypoint at (263.29, 236.18)
# Keypoint at (263.95, 437.06)
# Keypoint at (264.23, 112.27)
# Keypoint at (265.31, 445.56)
# Keypoint at (266.73, 311.08)
# Keypoint at (266.74, 294.57)
# Keypoint at (267.43, 227.50)
# Keypoint at (267.43, 227.50)
# Keypoint at (269.69, 457.52)
# Keypoint at (269.69, 457.52)
# Keypoint at (269.91, 111.98)
# Keypoint at (269.94, 474.16)
# Keypoint at (269.94, 474.16)
# Keypoint at (270.42, 302.20)
# Keypoint at (270.65, 293.56)
# Keypoint at (270.65, 293.56)
# Keypoint at (270.97, 287.46)
# Keypoint at (271.10, 19.54)
# Keypoint at (271.79, 287.74)
# Keypoint at (272.24, 560.51)
# Keypoint at (272.35, 563.80)
# Keypoint at (272.51, 314.17)
# Keypoint at (272.51, 314.17)
# Keypoint at (272.53, 438.90)
# Keypoint at (275.91, 445.88)
# Keypoint at (276.97, 297.84)
# Keypoint at (277.38, 563.00)
# Keypoint at (277.49, 105.84)
# Keypoint at (277.72, 159.86)
# Keypoint at (278.17, 78.80)
# Keypoint at (278.36, 434.14)
# Keypoint at (278.62, 518.82)
# Keypoint at (278.92, 302.97)
# Keypoint at (280.04, 289.34)
# Keypoint at (280.15, 17.73)
# Keypoint at (280.91, 441.05)
# Keypoint at (280.91, 441.05)
# Keypoint at (281.19, 455.52)
# Keypoint at (281.25, 12.30)
# Keypoint at (281.79, 568.02)
# Keypoint at (283.39, 293.42)
# Keypoint at (284.18, 468.49)
# Keypoint at (284.54, 468.26)
# Keypoint at (285.26, 559.03)
# Keypoint at (285.63, 549.06)
# Keypoint at (286.32, 540.70)
# Keypoint at (286.42, 232.70)
# Keypoint at (287.62, 14.46)
# Keypoint at (287.85, 433.70)
# Keypoint at (288.21, 522.24)
# Keypoint at (288.21, 522.24)
# Keypoint at (288.32, 477.93)
# Keypoint at (288.33, 447.05)
# Keypoint at (288.53, 111.33)
# Keypoint at (288.53, 111.33)
# Keypoint at (289.13, 438.02)
# Keypoint at (289.92, 428.76)
# Keypoint at (291.35, 12.72)
# Keypoint at (291.51, 28.57)
# Keypoint at (292.54, 292.29)
# Keypoint at (292.87, 440.58)
# Keypoint at (293.08, 506.44)
# Keypoint at (295.16, 277.90)
# Keypoint at (295.78, 429.98)
# Keypoint at (295.97, 458.17)
# Keypoint at (295.97, 458.17)
# Keypoint at (296.64, 121.29)
# Keypoint at (297.43, 110.85)
# Keypoint at (297.43, 110.85)
# Keypoint at (297.43, 110.85)
# Keypoint at (298.32, 473.22)
# Keypoint at (300.10, 449.97)
# Keypoint at (302.73, 438.94)
# Keypoint at (303.17, 180.45)
# Keypoint at (304.33, 448.28)
# Keypoint at (306.66, 144.34)
# Keypoint at (306.97, 139.43)
# Keypoint at (306.97, 139.43)
# Keypoint at (307.03, 266.60)
# Keypoint at (307.83, 121.38)
# Keypoint at (307.86, 208.38)
# Keypoint at (308.69, 24.48)
# Keypoint at (308.69, 72.87)
# Keypoint at (308.69, 72.87)
# Keypoint at (309.36, 254.14)
# Keypoint at (309.94, 430.21)
# Keypoint at (310.62, 145.97)
# Keypoint at (310.79, 138.27)
# Keypoint at (310.79, 138.27)
# Keypoint at (311.45, 248.14)
# Keypoint at (311.47, 27.27)
# Keypoint at (312.25, 111.14)
# Keypoint at (312.75, 401.71)
# Keypoint at (314.34, 127.28)
# Keypoint at (315.19, 232.65)
# Keypoint at (315.90, 119.47)
# Keypoint at (316.25, 444.40)
# Keypoint at (316.26, 251.06)
# Keypoint at (317.95, 300.51)
# Keypoint at (317.95, 300.51)
# Keypoint at (318.20, 264.90)
# Keypoint at (320.15, 237.79)
# Keypoint at (320.39, 446.56)
# Keypoint at (321.58, 247.60)
# Keypoint at (321.64, 147.56)
# Keypoint at (321.81, 34.00)
# Keypoint at (323.92, 208.62)
# Keypoint at (324.27, 150.77)
# Keypoint at (324.47, 212.69)
# Keypoint at (324.50, 23.60)
# Keypoint at (325.54, 115.51)
# Keypoint at (326.15, 223.40)
# Keypoint at (327.09, 245.23)
# Keypoint at (327.12, 203.05)
# Keypoint at (329.56, 141.24)
# Keypoint at (329.71, 211.04)
# Keypoint at (332.45, 153.71)
# Keypoint at (333.81, 219.02)
# Keypoint at (334.28, 43.38)
# Keypoint at (334.66, 114.83)
# Keypoint at (334.73, 179.26)
# Keypoint at (335.17, 225.85)
# Keypoint at (335.20, 246.55)
# Keypoint at (335.23, 5.93)
# Keypoint at (335.99, 243.30)
# Keypoint at (335.99, 243.30)
# Keypoint at (336.01, 191.18)
# Keypoint at (337.31, 221.49)
# Keypoint at (337.83, 3.26)
# Keypoint at (338.00, 201.43)
# Keypoint at (338.00, 201.43)
# Keypoint at (338.00, 201.43)
# Keypoint at (338.04, 180.32)
# Keypoint at (338.16, 216.83)
# Keypoint at (339.08, 80.02)
# Keypoint at (339.38, 119.62)
# Keypoint at (339.38, 111.91)
# Keypoint at (339.63, 245.57)
# Keypoint at (339.79, 30.91)
# Keypoint at (339.82, 12.11)
# Keypoint at (339.86, 171.05)
# Keypoint at (340.00, 209.61)
# Keypoint at (341.49, 214.50)
# Keypoint at (341.49, 217.75)
# Keypoint at (341.92, 49.33)
# Keypoint at (341.92, 49.33)
# Keypoint at (342.15, 202.76)
# Keypoint at (344.12, 179.07)
# Keypoint at (344.12, 179.07)
# Keypoint at (345.89, 380.34)
# Keypoint at (347.37, 183.00)
# Keypoint at (347.44, 202.79)
# Keypoint at (347.71, 389.67)
# Keypoint at (348.14, 205.76)
# Keypoint at (350.53, 141.39)
# Keypoint at (350.56, 175.13)
# Keypoint at (351.33, 235.70)
# Keypoint at (353.72, 204.71)
# Keypoint at (354.73, 392.85)
# Keypoint at (355.13, 110.69)
# Keypoint at (356.10, 11.36)
# Keypoint at (357.82, 3.47)
# Keypoint at (357.95, 376.46)
# Keypoint at (358.24, 371.34)
# Keypoint at (358.91, 117.99)
# Keypoint at (359.41, 191.73)
# Keypoint at (359.51, 201.08)
# Keypoint at (359.51, 201.08)
# Keypoint at (363.04, 47.80)
# Keypoint at (364.75, 197.89)
# Keypoint at (365.58, 85.34)
# Keypoint at (366.92, 357.54)
# Keypoint at (366.98, 219.73)
# Keypoint at (367.73, 25.22)
# Keypoint at (368.39, 192.56)
# Keypoint at (368.65, 24.25)
# Keypoint at (369.09, 224.05)
# Keypoint at (369.82, 178.23)
# Keypoint at (369.95, 179.09)
# Keypoint at (371.77, 214.55)
# Keypoint at (372.86, 117.10)
# Keypoint at (372.86, 117.10)
# Keypoint at (373.36, 369.72)
# Keypoint at (374.88, 183.57)
# Keypoint at (374.88, 183.57)
# Keypoint at (376.27, 66.73)
# Keypoint at (376.38, 42.30)
# Keypoint at (380.65, 482.33)
# Keypoint at (384.81, 90.48)
# Keypoint at (386.06, 57.09)
# Keypoint at (386.24, 38.80)
# Keypoint at (386.24, 38.80)
# Keypoint at (386.31, 230.53)
# Keypoint at (386.38, 66.62)
# Keypoint at (388.82, 208.45)
# Keypoint at (389.22, 214.87)
# Keypoint at (389.27, 224.22)
# Keypoint at (389.58, 52.09)
# Keypoint at (389.58, 52.09)
# Keypoint at (389.98, 42.49)
# Keypoint at (392.32, 37.93)
# Keypoint at (394.31, 225.88)
# Keypoint at (394.77, 194.57)
# Keypoint at (395.97, 217.78)
# Keypoint at (398.46, 501.86)
# Keypoint at (399.06, 73.93)
# Keypoint at (399.08, 359.06)
# Keypoint at (401.72, 517.67)
# Keypoint at (402.36, 120.49)
# Keypoint at (403.75, 493.54)
# Keypoint at (404.86, 562.53)
# Keypoint at (408.49, 27.44)
# Keypoint at (408.60, 45.24)
# Keypoint at (408.60, 45.24)
# Keypoint at (409.40, 67.78)
# Keypoint at (410.73, 48.07)
# Keypoint at (410.73, 48.07)
# Keypoint at (413.45, 484.67)
# Keypoint at (413.75, 337.10)
# Keypoint at (415.37, 240.49)
# Keypoint at (415.92, 234.29)
# Keypoint at (419.00, 503.85)
# Keypoint at (419.87, 38.77)
# Keypoint at (422.98, 44.52)
# Keypoint at (423.34, 557.94)
# Keypoint at (424.82, 480.98)
# Keypoint at (429.26, 488.29)
# Keypoint at (431.45, 225.03)
# Keypoint at (433.19, 563.66)
# Keypoint at (435.31, 553.70)
# Keypoint at (436.68, 529.53)
# Keypoint at (440.44, 266.58)
# Keypoint at (441.96, 250.21)
# Keypoint at (448.11, 542.07)
# Keypoint at (448.11, 542.07)
# Keypoint at (451.88, 530.45)
# Keypoint at (452.58, 567.37)
# Keypoint at (453.39, 544.62)
# Keypoint at (454.04, 541.05)
# Keypoint at (456.34, 511.01)
# Keypoint at (456.34, 511.01)
# Keypoint at (458.08, 520.14)
# Keypoint at (458.98, 280.63)
# Keypoint at (459.11, 559.15)
# Keypoint at (459.90, 329.09)
# Keypoint at (461.78, 554.67)
# Keypoint at (462.56, 249.48)
# Keypoint at (464.16, 329.96)
# Keypoint at (466.96, 41.26)
# Keypoint at (470.16, 527.98)
# Keypoint at (472.32, 277.35)
# Keypoint at (472.33, 52.90)
# Keypoint at (472.33, 52.90)
# Keypoint at (472.39, 552.57)
# Keypoint at (472.50, 44.88)
# Keypoint at (473.87, 48.81)
# Keypoint at (474.40, 492.68)
# Keypoint at (475.16, 39.63)
# Keypoint at (475.90, 504.79)
# Keypoint at (478.13, 551.31)
# Keypoint at (480.32, 69.32)
# Keypoint at (480.43, 100.02)
# Keypoint at (483.98, 25.74)
# Keypoint at (485.96, 42.93)
# Keypoint at (490.36, 497.91)
# Keypoint at (490.36, 497.91)
# Keypoint at (491.38, 109.46)
# Keypoint at (492.41, 555.45)
# Keypoint at (492.80, 363.64)
# Keypoint at (493.49, 387.70)
# Keypoint at (493.85, 529.47)
# Keypoint at (493.85, 529.47)
# Keypoint at (495.67, 480.94)
# Keypoint at (497.88, 366.55)
# Keypoint at (498.69, 113.07)
# Keypoint at (498.83, 479.94)
# Keypoint at (501.78, 515.66)
# Keypoint at (502.74, 216.00)
# Keypoint at (504.36, 418.08)
# Keypoint at (507.78, 431.84)
# Keypoint at (507.78, 431.84)

# %%
img = cv2.imread("eye_image/face3.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# query_face = cv2.imread('eye_image/face3.jpg')
# query_face_gray = cv2.cvtColor(query_face, cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT_create()
original_keypoints, original_descriptor = sift.detectAndCompute(gray, None)
# query_keypoints, query_descriptor = sift.detectAndCompute(query_face_gray, None)
keypoints_without_size = np.copy(img)
cv2.drawKeypoints(img, original_keypoints, keypoints_without_size, color = (0, 255, 0))

keypoints_with_size = np.copy(img)
cv2.drawKeypoints(img, original_keypoints, keypoints_with_size, flags = 
cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

for i in original_keypoints:
    x,y = i.pt
    print(f"Keypoint at ({x:.2f}, {y:.2f})")

cv2.imshow('Keypoints without size', keypoints_without_size)
cv2.imshow('Keypoints with size', keypoints_with_size)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Keypoint at (4.48, 852.97)
# Keypoint at (10.61, 106.49)
# Keypoint at (10.82, 511.24)
# Keypoint at (10.82, 511.24)
# Keypoint at (14.05, 522.80)
# Keypoint at (18.68, 553.10)
# Keypoint at (19.63, 520.15)
# Keypoint at (20.58, 645.97)
# Keypoint at (22.75, 544.50)
# Keypoint at (22.98, 545.06)
# Keypoint at (25.86, 573.94)
# Keypoint at (26.17, 559.99)
# Keypoint at (26.17, 559.99)
# Keypoint at (28.62, 611.88)
# Keypoint at (29.07, 605.95)
# Keypoint at (29.28, 621.06)
# Keypoint at (29.41, 626.11)
# Keypoint at (29.41, 626.11)
# Keypoint at (29.51, 597.85)
# Keypoint at (31.10, 825.51)
# Keypoint at (32.41, 833.34)
# Keypoint at (34.94, 603.02)
# Keypoint at (39.20, 105.47)
# Keypoint at (39.93, 670.09)
# Keypoint at (40.07, 881.39)
# Keypoint at (40.81, 552.20)
# Keypoint at (40.87, 881.12)
# Keypoint at (44.37, 596.20)
# Keypoint at (44.61, 602.46)
# Keypoint at (45.56, 556.17)
# Keypoint at (45.80, 619.90)
# Keypoint at (46.16, 598.77)
# Keypoint at (46.95, 592.94)
# Keypoint at (50.06, 897.22)
# Keypoint at (50.97, 890.26)
# Keypoint at (51.20, 533.75)
# Keypoint at (52.45, 551.68)
# Keypoint at (53.09, 551.38)
# Keypoint at (54.10, 601.29)
# Keypoint at (55.23, 596.21)
# Keypoint at (58.30, 593.04)
# Keypoint at (60.60, 595.12)
# Keypoint at (61.05, 922.25)
# Keypoint at (62.49, 597.73)
# Keypoint at (62.99, 341.08)
# Keypoint at (67.84, 602.31)
# Keypoint at (68.54, 593.79)
# Keypoint at (75.54, 592.79)
# Keypoint at (85.73, 524.93)
# Keypoint at (86.64, 533.81)
# Keypoint at (95.90, 542.23)
# Keypoint at (102.46, 385.27)
# Keypoint at (104.73, 589.30)
# Keypoint at (104.73, 589.30)
# Keypoint at (105.22, 583.18)
# Keypoint at (109.80, 524.83)
# Keypoint at (114.05, 628.33)
# Keypoint at (117.18, 528.53)
# Keypoint at (117.56, 538.01)
# Keypoint at (119.67, 520.43)
# Keypoint at (121.07, 526.74)
# Keypoint at (123.96, 509.08)
# Keypoint at (124.18, 513.81)
# Keypoint at (124.30, 319.70)
# Keypoint at (124.30, 319.70)
# Keypoint at (124.95, 549.94)
# Keypoint at (125.30, 540.14)
# Keypoint at (126.93, 509.37)
# Keypoint at (126.93, 509.37)
# Keypoint at (127.22, 438.76)
# Keypoint at (127.32, 450.94)
# Keypoint at (127.87, 503.73)
# Keypoint at (128.73, 514.07)
# Keypoint at (128.99, 499.29)
# Keypoint at (129.16, 458.98)
# Keypoint at (129.27, 513.92)
# Keypoint at (130.25, 506.26)
# Keypoint at (131.56, 440.45)
# Keypoint at (132.08, 463.63)
# Keypoint at (132.35, 543.33)
# Keypoint at (132.46, 436.22)
# Keypoint at (133.55, 390.25)
# Keypoint at (134.27, 585.92)
# Keypoint at (134.27, 585.92)
# Keypoint at (134.80, 557.25)
# Keypoint at (134.82, 378.63)
# Keypoint at (136.02, 590.76)
# Keypoint at (136.09, 610.89)
# Keypoint at (136.10, 391.39)
# Keypoint at (136.77, 458.37)
# Keypoint at (137.00, 382.83)
# Keypoint at (137.86, 330.75)
# Keypoint at (138.03, 570.41)
# Keypoint at (138.41, 356.98)
# Keypoint at (138.73, 395.69)
# Keypoint at (139.07, 428.70)
# Keypoint at (139.37, 455.55)
# Keypoint at (139.43, 580.42)
# Keypoint at (139.67, 390.60)
# Keypoint at (139.68, 433.87)
# Keypoint at (140.04, 419.69)
# Keypoint at (140.28, 353.57)
# Keypoint at (140.51, 428.19)
# Keypoint at (141.87, 367.01)
# Keypoint at (142.27, 306.05)
# Keypoint at (142.72, 355.10)
# Keypoint at (142.75, 584.46)
# Keypoint at (142.75, 584.46)
# Keypoint at (143.16, 447.83)
# Keypoint at (143.89, 587.97)
# Keypoint at (145.18, 453.56)
# Keypoint at (145.57, 463.03)
# Keypoint at (145.57, 463.03)
# Keypoint at (145.81, 458.62)
# Keypoint at (145.81, 458.62)
# Keypoint at (145.96, 431.26)
# Keypoint at (146.80, 315.29)
# Keypoint at (147.01, 591.73)
# Keypoint at (147.55, 460.96)
# Keypoint at (147.92, 600.26)
# Keypoint at (148.04, 318.34)
# Keypoint at (148.25, 300.55)
# Keypoint at (148.55, 320.30)
# Keypoint at (149.30, 312.18)
# Keypoint at (150.35, 445.17)
# Keypoint at (150.61, 323.33)
# Keypoint at (151.91, 309.44)
# Keypoint at (152.01, 589.99)
# Keypoint at (152.60, 451.92)
# Keypoint at (152.94, 327.80)
# Keypoint at (152.94, 327.80)
# Keypoint at (153.68, 576.18)
# Keypoint at (153.76, 293.99)
# Keypoint at (154.41, 595.72)
# Keypoint at (155.50, 322.03)
# Keypoint at (155.92, 297.75)
# Keypoint at (156.95, 290.79)
# Keypoint at (156.95, 290.79)
# Keypoint at (157.45, 317.65)
# Keypoint at (157.75, 607.41)
# Keypoint at (157.94, 326.66)
# Keypoint at (158.19, 309.01)
# Keypoint at (158.71, 300.43)
# Keypoint at (158.78, 635.77)
# Keypoint at (159.82, 474.45)
# Keypoint at (159.93, 443.29)
# Keypoint at (161.00, 613.56)
# Keypoint at (161.32, 291.63)
# Keypoint at (162.50, 421.90)
# Keypoint at (164.02, 418.52)
# Keypoint at (164.26, 439.39)
# Keypoint at (164.59, 438.08)
# Keypoint at (165.35, 440.33)
# Keypoint at (165.39, 292.05)
# Keypoint at (166.24, 451.39)
# Keypoint at (166.24, 451.39)
# Keypoint at (167.47, 441.44)
# Keypoint at (167.47, 441.44)
# Keypoint at (168.00, 301.24)
# Keypoint at (169.06, 280.29)
# Keypoint at (170.35, 401.68)
# Keypoint at (171.53, 438.87)
# Keypoint at (172.18, 634.74)
# Keypoint at (172.42, 337.44)
# Keypoint at (172.78, 433.12)
# Keypoint at (173.05, 301.51)
# Keypoint at (173.22, 284.95)
# Keypoint at (174.86, 290.53)
# Keypoint at (174.86, 290.53)
# Keypoint at (174.93, 294.00)
# Keypoint at (175.69, 627.06)
# Keypoint at (175.83, 309.35)
# Keypoint at (176.51, 281.99)
# Keypoint at (176.75, 336.20)
# Keypoint at (177.45, 315.25)
# Keypoint at (177.64, 295.63)
# Keypoint at (179.47, 656.93)
# Keypoint at (180.64, 335.91)
# Keypoint at (180.64, 335.91)
# Keypoint at (180.83, 661.28)
# Keypoint at (181.02, 367.28)
# Keypoint at (182.26, 307.85)
# Keypoint at (183.43, 334.26)
# Keypoint at (184.45, 292.64)
# Keypoint at (185.36, 337.62)
# Keypoint at (185.50, 368.42)
# Keypoint at (185.87, 301.20)
# Keypoint at (185.87, 301.20)
# Keypoint at (186.53, 270.32)
# Keypoint at (187.16, 281.08)
# Keypoint at (187.16, 281.08)
# Keypoint at (187.84, 273.80)
# Keypoint at (189.39, 267.94)
# Keypoint at (190.65, 285.25)
# Keypoint at (191.33, 302.10)
# Keypoint at (191.45, 459.72)
# Keypoint at (191.57, 291.36)
# Keypoint at (192.41, 269.49)
# Keypoint at (192.44, 294.72)
# Keypoint at (192.87, 264.40)
# Keypoint at (195.76, 286.42)
# Keypoint at (196.77, 290.49)
# Keypoint at (196.95, 262.03)
# Keypoint at (197.17, 414.00)
# Keypoint at (197.46, 516.68)
# Keypoint at (198.13, 420.17)
# Keypoint at (198.52, 278.85)
# Keypoint at (199.62, 842.25)
# Keypoint at (200.97, 453.90)
# Keypoint at (203.57, 468.57)
# Keypoint at (203.91, 278.17)
# Keypoint at (204.01, 260.82)
# Keypoint at (204.21, 461.89)
# Keypoint at (205.17, 842.71)
# Keypoint at (205.17, 842.71)
# Keypoint at (206.06, 282.88)
# Keypoint at (206.52, 265.44)
# Keypoint at (207.16, 818.55)
# Keypoint at (208.12, 824.06)
# Keypoint at (208.57, 823.33)
# Keypoint at (208.65, 461.36)
# Keypoint at (211.77, 453.02)
# Keypoint at (211.97, 831.27)
# Keypoint at (211.97, 831.27)
# Keypoint at (212.12, 456.15)
# Keypoint at (212.31, 816.47)
# Keypoint at (212.83, 311.77)
# Keypoint at (212.98, 820.99)
# Keypoint at (212.98, 820.99)
# Keypoint at (213.29, 267.07)
# Keypoint at (215.39, 424.59)
# Keypoint at (216.26, 285.00)
# Keypoint at (216.30, 843.23)
# Keypoint at (216.30, 843.23)
# Keypoint at (217.56, 296.55)
# Keypoint at (217.56, 296.55)
# Keypoint at (217.72, 825.39)
# Keypoint at (217.72, 825.39)
# Keypoint at (218.05, 835.02)
# Keypoint at (218.05, 835.02)
# Keypoint at (218.13, 291.72)
# Keypoint at (218.92, 819.86)
# Keypoint at (219.53, 277.36)
# Keypoint at (220.22, 601.32)
# Keypoint at (220.50, 455.23)
# Keypoint at (220.77, 462.22)
# Keypoint at (222.04, 843.64)
# Keypoint at (222.96, 819.82)
# Keypoint at (223.83, 244.08)
# Keypoint at (225.15, 606.19)
# Keypoint at (226.38, 274.21)
# Keypoint at (226.99, 671.47)
# Keypoint at (227.03, 306.45)
# Keypoint at (227.52, 284.38)
# Keypoint at (228.04, 460.44)
# Keypoint at (228.98, 828.52)
# Keypoint at (228.98, 828.52)
# Keypoint at (228.98, 828.52)
# Keypoint at (229.00, 298.56)
# Keypoint at (229.67, 242.97)
# Keypoint at (229.67, 242.97)
# Keypoint at (229.88, 283.02)
# Keypoint at (231.08, 823.71)
# Keypoint at (231.23, 466.39)
# Keypoint at (231.49, 607.38)
# Keypoint at (231.49, 607.38)
# Keypoint at (232.05, 287.36)
# Keypoint at (232.60, 608.13)
# Keypoint at (232.70, 396.93)
# Keypoint at (233.41, 158.06)
# Keypoint at (233.41, 158.06)
# Keypoint at (233.58, 281.64)
# Keypoint at (234.41, 273.47)
# Keypoint at (234.41, 273.47)
# Keypoint at (234.47, 611.12)
# Keypoint at (234.96, 827.08)
# Keypoint at (234.96, 827.08)
# Keypoint at (235.83, 441.89)
# Keypoint at (236.20, 762.86)
# Keypoint at (236.44, 280.74)
# Keypoint at (237.64, 221.18)
# Keypoint at (237.92, 297.24)
# Keypoint at (238.31, 471.01)
# Keypoint at (238.47, 825.37)
# Keypoint at (238.63, 829.54)
# Keypoint at (238.94, 851.11)
# Keypoint at (239.53, 553.26)
# Keypoint at (239.53, 553.26)
# Keypoint at (240.06, 443.54)
# Keypoint at (240.13, 292.60)
# Keypoint at (240.13, 292.60)
# Keypoint at (240.87, 611.05)
# Keypoint at (240.87, 611.05)
# Keypoint at (241.44, 279.05)
# Keypoint at (242.36, 853.92)
# Keypoint at (242.83, 841.71)
# Keypoint at (242.83, 841.71)
# Keypoint at (243.18, 820.70)
# Keypoint at (243.40, 825.18)
# Keypoint at (243.40, 825.18)
# Keypoint at (244.18, 850.25)
# Keypoint at (244.18, 850.25)
# Keypoint at (244.18, 850.25)
# Keypoint at (244.64, 243.51)
# Keypoint at (245.10, 276.06)
# Keypoint at (246.30, 617.72)
# Keypoint at (246.30, 617.72)
# Keypoint at (247.65, 607.13)
# Keypoint at (247.67, 559.52)
# Keypoint at (247.70, 841.65)
# Keypoint at (248.42, 835.10)
# Keypoint at (248.42, 835.10)
# Keypoint at (248.83, 454.41)
# Keypoint at (249.04, 285.45)
# Keypoint at (249.14, 825.46)
# Keypoint at (249.14, 825.46)
# Keypoint at (249.18, 261.26)
# Keypoint at (249.32, 853.12)
# Keypoint at (249.43, 270.75)
# Keypoint at (249.81, 280.43)
# Keypoint at (249.81, 280.43)
# Keypoint at (250.48, 294.93)
# Keypoint at (251.03, 490.26)
# Keypoint at (251.92, 837.40)
# Keypoint at (251.92, 485.70)
# Keypoint at (252.70, 482.68)
# Keypoint at (252.82, 832.65)
# Keypoint at (252.82, 832.65)
# Keypoint at (252.87, 459.19)
# Keypoint at (252.92, 845.88)
# Keypoint at (252.93, 275.71)
# Keypoint at (252.93, 275.71)
# Keypoint at (252.98, 841.46)
# Keypoint at (253.15, 851.50)
# Keypoint at (253.73, 308.19)
# Keypoint at (253.99, 493.70)
# Keypoint at (254.46, 278.57)
# Keypoint at (254.46, 278.57)
# Keypoint at (254.49, 612.97)
# Keypoint at (254.81, 824.39)
# Keypoint at (254.81, 824.39)
# Keypoint at (254.94, 848.60)
# Keypoint at (254.94, 848.60)
# Keypoint at (255.95, 820.04)
# Keypoint at (256.73, 852.49)
# Keypoint at (257.04, 274.13)
# Keypoint at (257.04, 274.13)
# Keypoint at (257.05, 468.59)
# Keypoint at (257.07, 846.63)
# Keypoint at (257.07, 846.63)
# Keypoint at (257.15, 242.65)
# Keypoint at (257.88, 496.04)
# Keypoint at (258.17, 472.01)
# Keypoint at (258.86, 838.80)
# Keypoint at (259.16, 842.02)
# Keypoint at (259.16, 842.02)
# Keypoint at (259.44, 293.31)
# Keypoint at (259.61, 821.64)
# Keypoint at (259.61, 821.64)
# Keypoint at (260.00, 492.38)
# Keypoint at (260.04, 849.62)
# Keypoint at (260.57, 227.00)
# Keypoint at (260.84, 846.62)
# Keypoint at (261.11, 464.83)
# Keypoint at (261.16, 261.08)
# Keypoint at (261.87, 853.59)
# Keypoint at (261.87, 273.26)
# Keypoint at (262.23, 837.10)
# Keypoint at (262.23, 837.10)
# Keypoint at (262.38, 612.94)
# Keypoint at (262.38, 612.94)
# Keypoint at (262.77, 484.90)
# Keypoint at (262.89, 624.59)
# Keypoint at (263.64, 850.73)
# Keypoint at (264.15, 825.88)
# Keypoint at (264.69, 236.12)
# Keypoint at (264.73, 253.62)
# Keypoint at (264.79, 228.57)
# Keypoint at (264.81, 838.35)
# Keypoint at (264.81, 838.35)
# Keypoint at (264.94, 270.00)
# Keypoint at (265.05, 285.54)
# Keypoint at (265.37, 471.63)
# Keypoint at (265.37, 471.63)
# Keypoint at (265.59, 835.75)
# Keypoint at (265.59, 835.75)
# Keypoint at (265.83, 855.05)
# Keypoint at (265.83, 855.05)
# Keypoint at (266.30, 290.04)
# Keypoint at (266.54, 848.27)
# Keypoint at (266.54, 848.27)
# Keypoint at (267.11, 241.74)
# Keypoint at (267.12, 844.13)
# Keypoint at (267.12, 844.13)
# Keypoint at (267.43, 586.56)
# Keypoint at (267.59, 561.08)
# Keypoint at (267.92, 260.54)
# Keypoint at (268.60, 851.61)
# Keypoint at (268.60, 851.61)
# Keypoint at (269.09, 228.23)
# Keypoint at (269.39, 837.18)
# Keypoint at (269.39, 837.18)
# Keypoint at (269.71, 854.75)
# Keypoint at (269.82, 826.69)
# Keypoint at (269.82, 826.69)
# Keypoint at (270.39, 240.99)
# Keypoint at (271.28, 248.73)
# Keypoint at (271.28, 248.73)
# Keypoint at (271.55, 255.06)
# Keypoint at (271.63, 244.55)
# Keypoint at (271.78, 842.50)
# Keypoint at (271.78, 842.50)
# Keypoint at (271.91, 858.14)
# Keypoint at (272.71, 295.31)
# Keypoint at (272.71, 295.31)
# Keypoint at (274.32, 855.80)
# Keypoint at (275.12, 253.10)
# Keypoint at (275.14, 289.59)
# Keypoint at (275.39, 826.53)
# Keypoint at (275.56, 281.96)
# Keypoint at (275.77, 845.07)
# Keypoint at (275.77, 845.07)
# Keypoint at (275.88, 275.22)
# Keypoint at (276.46, 838.33)
# Keypoint at (276.89, 833.25)
# Keypoint at (277.09, 854.50)
# Keypoint at (277.09, 854.50)
# Keypoint at (277.10, 247.94)
# Keypoint at (277.29, 230.04)
# Keypoint at (277.31, 300.15)
# Keypoint at (278.48, 260.19)
# Keypoint at (279.18, 843.04)
# Keypoint at (279.31, 242.85)
# Keypoint at (279.47, 288.01)
# Keypoint at (279.85, 617.65)
# Keypoint at (280.74, 254.86)
# Keypoint at (280.96, 830.14)
# Keypoint at (280.96, 830.14)
# Keypoint at (281.82, 221.10)
# Keypoint at (281.82, 221.10)
# Keypoint at (281.96, 304.02)
# Keypoint at (282.11, 834.25)
# Keypoint at (282.11, 834.25)
# Keypoint at (282.21, 845.19)
# Keypoint at (283.53, 310.70)
# Keypoint at (283.68, 295.01)
# Keypoint at (283.85, 826.72)
# Keypoint at (283.88, 223.60)
# Keypoint at (284.32, 301.46)
# Keypoint at (284.54, 852.57)
# Keypoint at (285.08, 306.65)
# Keypoint at (285.50, 844.40)
# Keypoint at (285.82, 855.85)
# Keypoint at (285.82, 855.85)
# Keypoint at (286.11, 225.83)
# Keypoint at (286.11, 225.83)
# Keypoint at (286.71, 852.79)
# Keypoint at (287.19, 617.69)
# Keypoint at (287.51, 851.27)
# Keypoint at (287.71, 272.86)
# Keypoint at (287.93, 840.04)
# Keypoint at (287.93, 840.04)
# Keypoint at (288.40, 827.08)
# Keypoint at (288.40, 827.08)
# Keypoint at (288.52, 221.05)
# Keypoint at (288.52, 221.05)
# Keypoint at (288.66, 855.53)
# Keypoint at (288.66, 855.53)
# Keypoint at (288.98, 831.53)
# Keypoint at (289.22, 848.59)
# Keypoint at (289.73, 276.06)
# Keypoint at (289.91, 857.74)
# Keypoint at (289.91, 857.74)
# Keypoint at (290.13, 226.14)
# Keypoint at (291.23, 854.12)
# Keypoint at (291.43, 304.03)
# Keypoint at (291.73, 258.62)
# Keypoint at (291.73, 258.62)
# Keypoint at (291.86, 848.64)
# Keypoint at (292.01, 843.75)
# Keypoint at (292.01, 843.75)
# Keypoint at (292.53, 248.89)
# Keypoint at (292.55, 252.99)
# Keypoint at (292.68, 828.07)
# Keypoint at (292.68, 828.07)
# Keypoint at (292.98, 835.93)
# Keypoint at (293.36, 244.59)
# Keypoint at (293.36, 244.59)
# Keypoint at (293.63, 852.51)
# Keypoint at (294.38, 468.33)
# Keypoint at (294.45, 222.98)
# Keypoint at (294.49, 475.60)
# Keypoint at (294.49, 475.60)
# Keypoint at (294.51, 565.66)
# Keypoint at (294.56, 617.88)
# Keypoint at (294.82, 858.22)
# Keypoint at (294.93, 424.61)
# Keypoint at (295.04, 262.51)
# Keypoint at (295.04, 262.51)
# Keypoint at (295.67, 283.12)
# Keypoint at (296.33, 225.43)
# Keypoint at (296.60, 241.60)
# Keypoint at (296.60, 241.60)
# Keypoint at (297.06, 289.33)
# Keypoint at (297.18, 624.73)
# Keypoint at (298.15, 479.04)
# Keypoint at (298.20, 220.05)
# Keypoint at (298.27, 564.12)
# Keypoint at (298.40, 223.06)
# Keypoint at (298.45, 257.92)
# Keypoint at (298.45, 257.92)
# Keypoint at (299.66, 274.15)
# Keypoint at (299.97, 469.96)
# Keypoint at (300.14, 226.84)
# Keypoint at (300.14, 226.84)
# Keypoint at (300.61, 266.03)
# Keypoint at (302.13, 475.54)
# Keypoint at (302.19, 257.14)
# Keypoint at (302.94, 488.29)
# Keypoint at (302.94, 488.29)
# Keypoint at (303.06, 502.24)
# Keypoint at (304.57, 618.31)
# Keypoint at (304.61, 224.25)
# Keypoint at (305.17, 229.33)
# Keypoint at (305.78, 490.13)
# Keypoint at (306.12, 495.12)
# Keypoint at (306.12, 495.12)
# Keypoint at (307.50, 609.91)
# Keypoint at (307.55, 308.91)
# Keypoint at (308.45, 242.34)
# Keypoint at (308.75, 611.06)
# Keypoint at (308.97, 230.84)
# Keypoint at (308.98, 459.90)
# Keypoint at (309.46, 266.86)
# Keypoint at (310.07, 290.93)
# Keypoint at (310.07, 290.93)
# Keypoint at (310.07, 238.73)
# Keypoint at (310.54, 302.77)
# Keypoint at (310.54, 302.77)
# Keypoint at (311.19, 235.53)
# Keypoint at (311.65, 621.24)
# Keypoint at (311.65, 621.24)
# Keypoint at (312.22, 464.31)
# Keypoint at (313.27, 282.07)
# Keypoint at (313.41, 263.06)
# Keypoint at (313.70, 249.56)
# Keypoint at (315.70, 280.13)
# Keypoint at (315.70, 280.13)
# Keypoint at (316.49, 456.06)
# Keypoint at (317.03, 287.15)
# Keypoint at (317.87, 299.49)
# Keypoint at (318.09, 271.19)
# Keypoint at (318.27, 461.63)
# Keypoint at (318.33, 251.40)
# Keypoint at (318.33, 251.40)
# Keypoint at (318.86, 458.19)
# Keypoint at (318.86, 458.19)
# Keypoint at (321.47, 284.64)
# Keypoint at (321.48, 289.52)
# Keypoint at (321.87, 230.32)
# Keypoint at (322.70, 315.08)
# Keypoint at (323.32, 242.03)
# Keypoint at (323.78, 480.71)
# Keypoint at (323.78, 480.71)
# Keypoint at (323.92, 276.80)
# Keypoint at (323.92, 276.80)
# Keypoint at (324.51, 297.10)
# Keypoint at (324.65, 286.93)
# Keypoint at (324.99, 293.53)
# Keypoint at (325.06, 310.79)
# Keypoint at (325.06, 310.79)
# Keypoint at (325.66, 237.21)
# Keypoint at (327.71, 288.30)
# Keypoint at (327.96, 266.40)
# Keypoint at (329.05, 265.90)
# Keypoint at (329.39, 334.72)
# Keypoint at (329.39, 334.72)
# Keypoint at (330.35, 227.07)
# Keypoint at (331.67, 478.24)
# Keypoint at (333.09, 237.87)
# Keypoint at (333.10, 268.04)
# Keypoint at (333.17, 276.42)
# Keypoint at (333.59, 235.70)
# Keypoint at (333.66, 284.19)
# Keypoint at (335.92, 228.30)
# Keypoint at (336.04, 472.08)
# Keypoint at (336.69, 279.45)
# Keypoint at (338.60, 656.65)
# Keypoint at (339.47, 273.52)
# Keypoint at (339.47, 273.52)
# Keypoint at (339.71, 233.75)
# Keypoint at (341.33, 256.32)
# Keypoint at (341.67, 262.31)
# Keypoint at (341.67, 262.31)
# Keypoint at (341.69, 443.49)
# Keypoint at (343.01, 271.44)
# Keypoint at (343.01, 271.44)
# Keypoint at (343.34, 652.41)
# Keypoint at (344.22, 268.14)
# Keypoint at (344.69, 260.07)
# Keypoint at (345.19, 464.14)
# Keypoint at (346.02, 269.96)
# Keypoint at (346.07, 452.61)
# Keypoint at (346.07, 452.61)
# Keypoint at (347.24, 483.34)
# Keypoint at (348.09, 648.57)
# Keypoint at (348.13, 267.83)
# Keypoint at (348.50, 477.95)
# Keypoint at (348.60, 277.94)
# Keypoint at (349.14, 651.97)
# Keypoint at (349.36, 308.71)
# Keypoint at (349.36, 308.71)
# Keypoint at (349.79, 664.23)
# Keypoint at (350.09, 259.80)
# Keypoint at (351.43, 272.39)
# Keypoint at (352.64, 242.14)
# Keypoint at (352.74, 261.31)
# Keypoint at (352.74, 261.31)
# Keypoint at (352.85, 314.56)
# Keypoint at (353.30, 473.28)
# Keypoint at (353.30, 473.28)
# Keypoint at (354.68, 247.09)
# Keypoint at (354.73, 293.66)
# Keypoint at (355.39, 641.18)
# Keypoint at (355.39, 466.61)
# Keypoint at (355.84, 275.70)
# Keypoint at (356.70, 316.75)
# Keypoint at (358.38, 284.38)
# Keypoint at (358.44, 459.96)
# Keypoint at (358.67, 255.17)
# Keypoint at (358.67, 255.17)
# Keypoint at (359.29, 247.27)
# Keypoint at (360.98, 478.92)
# Keypoint at (361.50, 251.48)
# Keypoint at (361.50, 251.48)
# Keypoint at (361.60, 259.03)
# Keypoint at (361.60, 259.03)
# Keypoint at (361.83, 243.07)
# Keypoint at (362.07, 440.46)
# Keypoint at (363.06, 294.23)
# Keypoint at (363.77, 235.64)
# Keypoint at (365.45, 303.00)
# Keypoint at (365.45, 303.00)
# Keypoint at (365.57, 577.28)
# Keypoint at (365.94, 321.53)
# Keypoint at (366.09, 472.28)
# Keypoint at (366.16, 266.24)
# Keypoint at (366.99, 244.98)
# Keypoint at (366.99, 244.98)
# Keypoint at (367.77, 293.38)
# Keypoint at (367.77, 293.38)
# Keypoint at (369.31, 312.37)
# Keypoint at (369.49, 256.36)
# Keypoint at (370.31, 544.65)
# Keypoint at (370.55, 320.38)
# Keypoint at (371.04, 288.91)
# Keypoint at (371.08, 245.10)
# Keypoint at (371.51, 283.76)
# Keypoint at (371.61, 261.34)
# Keypoint at (371.61, 261.34)
# Keypoint at (371.64, 291.22)
# Keypoint at (372.79, 249.21)
# Keypoint at (372.79, 249.21)
# Keypoint at (372.83, 481.42)
# Keypoint at (372.83, 481.42)
# Keypoint at (372.89, 630.27)
# Keypoint at (373.57, 309.71)
# Keypoint at (373.96, 316.81)
# Keypoint at (374.27, 398.32)
# Keypoint at (376.01, 303.62)
# Keypoint at (377.13, 275.54)
# Keypoint at (377.37, 266.26)
# Keypoint at (378.44, 286.06)
# Keypoint at (378.64, 355.03)
# Keypoint at (378.67, 281.96)
# Keypoint at (381.43, 617.13)
# Keypoint at (382.10, 542.93)
# Keypoint at (382.28, 322.69)
# Keypoint at (382.28, 322.69)
# Keypoint at (382.45, 271.89)
# Keypoint at (382.88, 620.64)
# Keypoint at (382.90, 303.76)
# Keypoint at (385.12, 438.90)
# Keypoint at (385.12, 438.90)
# Keypoint at (385.15, 300.29)
# Keypoint at (385.98, 268.58)
# Keypoint at (385.98, 268.58)
# Keypoint at (387.18, 288.20)
# Keypoint at (388.16, 312.13)
# Keypoint at (388.16, 312.13)
# Keypoint at (388.54, 270.23)
# Keypoint at (388.85, 537.64)
# Keypoint at (388.85, 537.64)
# Keypoint at (389.21, 610.48)
# Keypoint at (389.83, 533.51)
# Keypoint at (390.09, 472.73)
# Keypoint at (390.09, 472.73)
# Keypoint at (390.49, 274.68)
# Keypoint at (390.54, 291.91)
# Keypoint at (390.76, 283.54)
# Keypoint at (391.58, 276.05)
# Keypoint at (392.22, 289.59)
# Keypoint at (392.22, 289.59)
# Keypoint at (393.08, 309.61)
# Keypoint at (393.08, 309.61)
# Keypoint at (395.49, 290.02)
# Keypoint at (395.49, 290.02)
# Keypoint at (395.88, 314.33)
# Keypoint at (395.88, 314.33)
# Keypoint at (395.98, 284.42)
# Keypoint at (396.38, 604.71)
# Keypoint at (396.38, 604.71)
# Keypoint at (397.57, 601.13)
# Keypoint at (397.86, 287.16)
# Keypoint at (398.57, 296.16)
# Keypoint at (398.82, 291.34)
# Keypoint at (399.50, 286.31)
# Keypoint at (399.71, 276.96)
# Keypoint at (399.96, 419.18)
# Keypoint at (400.21, 482.03)
# Keypoint at (400.31, 292.77)
# Keypoint at (403.83, 596.41)
# Keypoint at (403.95, 578.52)
# Keypoint at (404.51, 291.42)
# Keypoint at (405.39, 309.02)
# Keypoint at (406.23, 625.62)
# Keypoint at (406.36, 565.52)
# Keypoint at (406.55, 303.43)
# Keypoint at (406.66, 641.05)
# Keypoint at (408.52, 324.26)
# Keypoint at (409.19, 357.94)
# Keypoint at (409.19, 357.94)
# Keypoint at (409.28, 576.41)
# Keypoint at (409.38, 343.99)
# Keypoint at (409.73, 565.54)
# Keypoint at (410.38, 619.48)
# Keypoint at (410.38, 619.48)
# Keypoint at (410.89, 604.72)
# Keypoint at (411.47, 309.64)
# Keypoint at (411.55, 544.98)
# Keypoint at (412.24, 495.37)
# Keypoint at (412.39, 313.62)
# Keypoint at (412.68, 553.92)
# Keypoint at (414.18, 492.97)
# Keypoint at (415.32, 486.64)
# Keypoint at (415.42, 309.89)
# Keypoint at (418.28, 300.51)
# Keypoint at (418.29, 504.79)
# Keypoint at (418.77, 541.84)
# Keypoint at (420.06, 303.68)
# Keypoint at (420.30, 491.48)
# Keypoint at (421.74, 565.52)
# Keypoint at (421.74, 565.52)
# Keypoint at (422.36, 462.09)
# Keypoint at (422.68, 562.34)
# Keypoint at (424.55, 597.68)
# Keypoint at (424.63, 604.44)
# Keypoint at (424.82, 309.82)
# Keypoint at (427.33, 320.53)
# Keypoint at (427.56, 468.07)
# Keypoint at (429.00, 462.65)
# Keypoint at (430.29, 603.80)
# Keypoint at (430.73, 609.12)
# Keypoint at (431.31, 313.43)
# Keypoint at (431.50, 316.64)
# Keypoint at (431.54, 488.61)
# Keypoint at (432.46, 481.98)
# Keypoint at (433.73, 459.72)
# Keypoint at (434.28, 467.39)
# Keypoint at (434.50, 300.71)
# Keypoint at (435.88, 609.90)
# Keypoint at (436.51, 311.16)
# Keypoint at (437.11, 470.04)
# Keypoint at (439.13, 461.66)
# Keypoint at (440.00, 497.53)
# Keypoint at (440.50, 473.72)
# Keypoint at (440.98, 448.96)
# Keypoint at (441.67, 559.97)
# Keypoint at (441.99, 587.00)
# Keypoint at (442.13, 419.17)
# Keypoint at (444.04, 482.82)
# Keypoint at (444.82, 315.55)
# Keypoint at (445.73, 351.06)
# Keypoint at (445.85, 606.02)
# Keypoint at (448.39, 529.32)
# Keypoint at (450.50, 333.11)
# Keypoint at (450.97, 503.83)
# Keypoint at (452.87, 534.20)
# Keypoint at (453.24, 545.68)
# Keypoint at (455.58, 378.84)
# Keypoint at (456.33, 361.94)
# Keypoint at (456.63, 613.94)
# Keypoint at (458.28, 935.87)
# Keypoint at (459.43, 569.71)
# Keypoint at (459.67, 502.61)
# Keypoint at (461.33, 932.02)
# Keypoint at (462.61, 472.75)
# Keypoint at (464.18, 919.13)
# Keypoint at (465.70, 948.12)
# Keypoint at (468.70, 487.88)
# Keypoint at (469.66, 462.74)
# Keypoint at (470.27, 616.14)
# Keypoint at (470.41, 423.92)
# Keypoint at (471.07, 448.35)
# Keypoint at (471.37, 511.17)
# Keypoint at (472.09, 893.79)
# Keypoint at (474.51, 888.55)
# Keypoint at (475.43, 577.04)
# Keypoint at (475.86, 459.91)
# Keypoint at (476.43, 883.50)
# Keypoint at (476.55, 574.31)
# Keypoint at (477.80, 533.31)
# Keypoint at (477.80, 533.31)
# Keypoint at (478.22, 548.69)
# Keypoint at (479.91, 478.11)
# Keypoint at (481.38, 469.05)
# Keypoint at (481.38, 469.05)
# Keypoint at (482.18, 566.40)
# Keypoint at (484.41, 865.02)
# Keypoint at (484.86, 528.51)
# Keypoint at (485.18, 854.04)
# Keypoint at (486.41, 457.14)
# Keypoint at (488.89, 544.49)
# Keypoint at (488.95, 856.71)
# Keypoint at (489.41, 507.97)
# Keypoint at (489.70, 942.64)
# Keypoint at (490.02, 493.28)
# Keypoint at (490.34, 570.52)
# Keypoint at (491.43, 533.66)
# Keypoint at (491.57, 852.21)
# Keypoint at (491.60, 495.77)
# Keypoint at (491.84, 562.08)
# Keypoint at (493.52, 857.10)
# Keypoint at (494.18, 872.23)
# Keypoint at (494.46, 503.54)
# Keypoint at (494.54, 626.10)
# Keypoint at (496.89, 621.14)
# Keypoint at (496.92, 627.46)
# Keypoint at (496.95, 583.29)
# Keypoint at (496.96, 529.23)
# Keypoint at (498.10, 949.51)
# Keypoint at (498.12, 862.74)
# Keypoint at (498.32, 862.79)
# Keypoint at (499.77, 567.38)
# Keypoint at (500.02, 588.19)
# Keypoint at (500.96, 622.71)
# Keypoint at (502.83, 942.06)
# Keypoint at (502.83, 942.06)
# Keypoint at (503.69, 894.40)
# Keypoint at (504.76, 630.99)
# Keypoint at (506.84, 952.87)
# Keypoint at (507.04, 643.50)
# Keypoint at (507.06, 488.94)
# Keypoint at (507.85, 512.90)
# Keypoint at (507.91, 932.73)
# Keypoint at (508.09, 629.03)
# Keypoint at (508.09, 623.48)
# Keypoint at (508.19, 861.25)
# Keypoint at (508.87, 632.60)
# Keypoint at (509.23, 481.70)
# Keypoint at (510.12, 527.86)
# Keypoint at (510.73, 641.51)
# Keypoint at (511.72, 647.64)
# Keypoint at (512.19, 516.29)
# Keypoint at (512.20, 946.32)
# Keypoint at (512.20, 946.32)
# Keypoint at (512.39, 873.04)
# Keypoint at (513.62, 623.16)
# Keypoint at (514.15, 635.87)
# Keypoint at (514.82, 632.25)
# Keypoint at (514.82, 632.25)
# Keypoint at (515.93, 486.04)
# Keypoint at (516.95, 877.57)
# Keypoint at (517.14, 941.21)
# Keypoint at (517.17, 610.07)
# Keypoint at (520.55, 510.61)
# Keypoint at (520.83, 928.67)
# Keypoint at (522.58, 453.52)
# Keypoint at (522.58, 453.52)
# Keypoint at (522.58, 453.52)
# Keypoint at (523.04, 481.81)
# Keypoint at (523.20, 627.15)
# Keypoint at (524.33, 878.86)
# Keypoint at (527.06, 517.02)
# Keypoint at (528.43, 921.63)
# Keypoint at (528.65, 884.55)
# Keypoint at (529.85, 881.36)
# Keypoint at (530.27, 476.71)
# Keypoint at (530.27, 476.71)
# Keypoint at (530.95, 887.40)
# Keypoint at (531.65, 930.19)
# Keypoint at (531.94, 623.81)
# Keypoint at (532.55, 470.30)
# Keypoint at (533.57, 884.91)
# Keypoint at (535.12, 892.15)
